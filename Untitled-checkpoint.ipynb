# %%
import pandas as pd

# %%
data = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# **Project Proposal** : Review and complete the Project Proposal, as mentioned in the project description. Make sure to submit it to your instructor for review and approval before proceeding further.
#
# **Explore the Dataset**: Take some time to explore the King County House Sales dataset (kc_house_data.csv) that you have cloned. Familiarize yourself with the column names and the data contained in each column. You can refer to the column_names.md file in the same folder for descriptions of the column names.
#
# **Define Stakeholder and Business Problem**: Based on the dataset, define a stakeholder and a suitable business problem. As suggested in the project description, you can consider a real estate agency that helps homeowners buy and sell homes. For example, you could focus on providing advice to homeowners about how home renovations might increase the estimated value of their homes, and by what amount. Clearly articulate the stakeholder, their needs, and the specific business problem you will address.
#
# **Data Preparation**: Preprocess the dataset in preparation for modeling. This step includes handling missing values and converting non-numeric data into numeric format. Identify any missing values in the dataset and decide on an appropriate strategy for handling them, such as dropping or replacing the missing data. Also, identify non-numeric features and apply techniques like ordinal or one-hot encoding to convert them into a format suitable for modeling. Document your rationale for the preprocessing steps in the Jupyter Notebook.
#
# **Baseline Model**: Build a baseline linear regression model using the preprocessed dataset. This initial model will serve as a starting point for evaluation and further improvement. Implement the model and evaluate its performance using appropriate metrics such as R-squared or RMSE. Document the model and its evaluation results in the Jupyter Notebook.
#
# **Model Iteration**: Apply an iterative approach to modeling by refining and improving the baseline model. Consider making adjustments supported by regression theory or descriptive analysis of the data. This may involve feature selection, feature engineering, or other techniques to enhance model performance. Justify each iteration and document the changes made, along with the evaluation results, in the Jupyter Notebook.
#
# **Final Model**: Select a final model from your iterations that demonstrates improved performance and provides meaningful insights for your stakeholder's business problem. Report on the model's metrics, such as R-squared or RMSE, and interpret the coefficients of at least two features in plain language. Connect the results to real-world implications and discuss the limitations and uncertainties of your analysis. Provide recommendations to stakeholders based on the model's results.
#
# **Non-Technical Presentation**: Create a non-technical presentation slide deck that summarizes your analysis and findings. Follow the recommended structure provided in the project description, including sections like Overview, Business and Data Understanding, Modeling, Regression Results, Recommendations, and Next Steps. Ensure your presentation is geared towards a non-technical audience and clearly communicates the rationale, results, limitations, and recommendations of your statistical analyses.
#
# **Jupyter Notebook**: Develop a Jupyter Notebook that presents your analysis and modeling process to a data science audience. Include detailed explanations, code, visualizations, and markdown cells to convey your methodology, data preparation steps, modeling iterations, regression results, and code quality. The notebook should demonstrate clear organization and effective communication of your analysis.
#
# **GitHub Repository**: Create a GitHub repository to host your project files, including the Jupyter Notebook, non-technical presentation, and any other supporting materials. Follow the guidelines provided in the project description to structure your repository and README.md file. Commit your work to the repository regularly, ensuring proper version control and documenting your progress.

# %% [markdown]
# ## Project Proposal: Home Renovation Impact on House Value
#
# 1. Introduction:
# In this project, we aim to analyze the impact of home renovations on the estimated value of houses in the King County area. The goal is to provide homeowners with valuable insights and recommendations on which renovations are likely to increase their property value the most. By leveraging the King County House Sales dataset, we will build a predictive model that estimates the potential increase in house value based on different renovation features.
#
# 2. Objectives:
#
# Analyze the relationship between home renovation features and house sale prices in the King County area.
# Identify the renovation features that have the greatest impact on house value.
# Develop a predictive model to estimate the potential increase in house value based on selected renovation features.
# Provide actionable recommendations to homeowners on which renovations are likely to yield the highest return on investment.
# 3. Methodology:
# The project will follow the following key steps:
#
# Data Exploration: Conduct an in-depth exploration of the King County House Sales dataset to understand the available features, their descriptions, and their distribution.
# Data Preprocessing: Cleanse the dataset by handling missing values, outliers, and formatting issues. Perform feature engineering and transformation to prepare the data for modeling.
# Feature Selection: Identify the renovation features that exhibit the strongest correlation with house sale prices and select the most relevant ones for modeling.
# Model Development: Build a regression model to predict the increase in house value based on the selected renovation features. Utilize appropriate regression techniques and algorithms to achieve accurate predictions.
# Model Evaluation: Assess the performance of the developed model using appropriate evaluation metrics such as R-squared, root mean squared error (RMSE), and mean absolute error (MAE).
# Interpretation and Recommendations: Interpret the coefficients of the selected renovation features and provide clear explanations of their impact on house value. Use the model results to generate actionable recommendations for homeowners seeking to increase their property value through renovations.
# 4. Deliverables:
#
# A Jupyter Notebook presenting the entire data analysis process, including data exploration, preprocessing, feature selection, model development, and evaluation.
# A non-technical presentation slide deck summarizing the project's objectives, methodology, key findings, and recommendations for homeowners.
# A GitHub repository hosting all project files, ensuring proper version control and documentation.
# 6. Conclusion:
# This project aims to provide homeowners with valuable insights into the impact of home renovations on house value in the King County area. By developing a predictive model and offering actionable recommendations, homeowners can make informed decisions to maximize the return on their renovation investments. The analysis and findings will be documented in a comprehensive Jupyter Notebook and presented in a non-technical manner to ensure clarity and accessibility for a wide range of audiences.

# %%
num_records = len(data)

print("Number of records:", num_records)
# Out:
# Number of records: 21597

# %%
features = data.columns
print("Available features:", features)
# Out:
# Available features: Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# 1      7242     2.0         NO  NONE  ...      7 Average       2170
# 2     10000     1.0         NO  NONE  ...  6 Low Average        770
# 3      5000     1.0         NO  NONE  ...      7 Average       1050
# 4      8080     1.0         NO  NONE  ...         8 Good       1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 21592      1131     3.0         NO  NONE  ...     8 Good       1530
# 21593      5813     2.0         NO  NONE  ...     8 Good       2310
# 21594      1350     2.0         NO  NONE  ...  7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...     8 Good       1600
# 21596      1076     2.0         NO  NONE  ...  7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.sample
# Out:
# <bound method NDFrame.sample of                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
# ...

# %%
data.shape
# Out:
# (21597, 21)

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built  yr_renovated  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  17755.000000
# mean   1.509941e+04      1.494096   1788.596842   1970.999676     83.636778
# ...

# %% [markdown]
# **Introduction:**
# In this project, we will leverage the King County House Sales dataset, which contains detailed information about house sales in the area. By analyzing this dataset and applying advanced analytical techniques, we aim to provide valuable insights to support decision-making related to real estate investments, pricing strategies, and market trends.
#
# **Project Goals:**
# a) Develop a predictive model: Our primary goal is to build a robust predictive model that can estimate the sale price of houses accurately. This model will take into account relevant attributes such as the number of bedrooms, bathrooms, living area, lot area, condition, grade, and the year the house was built.
#
# b) Identify key factors affecting house prices: By analyzing the dataset, we will determine the significant factors that influence house prices in King County. Understanding these factors will help identify areas for improvement, inform marketing strategies, and provide insights for potential buyers and sellers.
#
# c) Provide actionable recommendations: Based on the analysis, we will generate actionable recommendations to enhance the decision-making process for real estate professionals, investors, and other stakeholders involved in the housing market.
#
# **Methodology:**
# a) Data Understanding: We will thoroughly explore the provided King County House Sales dataset, reviewing the column descriptions and gaining a comprehensive understanding of the available attributes.
#
# b) Data Preparation: We will preprocess the dataset, addressing missing values, outliers, and data inconsistencies. Feature engineering techniques will be applied to create new variables or transform existing ones to improve the predictive model's performance.
#
# c) Exploratory Data Analysis (EDA): We will conduct an in-depth EDA to identify patterns, correlations, and trends within the dataset. This analysis will help us understand the relationships between different variables and uncover insights related to house prices.
#
# d) Model Development: Using appropriate regression techniques, we will develop a predictive model to estimate house prices accurately. The model will be trained and evaluated using appropriate validation techniques, ensuring its reliability and generalizability.
#
# e) Interpretation and Reporting: We will interpret the model's results, identifying the most influential factors affecting house prices. Our findings will be presented in a clear and comprehensive report, including visualizations, summary statistics, and actionable recommendations.
#
# **Data Considerations:**
# We will primarily utilize the King County House Sales dataset (kc_house_data.csv) provided for this project. However, we may incorporate additional external data sources, such as economic indicators, neighborhood demographics, or local market trends, to enhance the analysis and improve the model's predictive power.
#
#
# **Deliverables:**
# Our deliverables will include the following:
#
# A detailed report summarizing the findings, including insights into key factors influencing house prices and the performance of the predictive model.
# Visualizations, statistical summaries, and charts illustrating important trends and relationships within the dataset.
# The developed predictive model, along with documentation on how to

# %%
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# sqft_above    -0.010799  0.605368  0.479386   0.686668     0.876448  0.184139
# yr_built       0.021617  0.053953  0.155670   0.507173     0.318152  0.052946
# yr_renovated  -0.012010  0.129599  0.018495   0.051050     0.055660  0.004513
# zipcode       -0.008211 -0.053402 -0.154092  -0.204786    -0.199802 -0.129586
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
#Finding the count of no. of bedrooms
data['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
#Finding the count of grade
data['grade'].value_counts()
# Out:
# 7 Average        8974
# 8 Good           6065
# 9 Better         2615
# 6 Low Average    2038
# 10 Very Good     1134
# 11 Excellent      399
# 5 Fair            242
# 12 Luxury          89
# 4 Low              27
# 13 Mansion         13
# 3 Poor              1
# Name: grade, dtype: int64

# %%
#Finding the count of floors
data['floors'].value_counts()
# Out:
# 1.0    10673
# 2.0     8235
# 1.5     1910
# 3.0      611
# 2.5      161
# 3.5        7
# Name: floors, dtype: int64

# %%
#Finding the count of no. of bathrooms
data['bathrooms'].value_counts()
# Out:
# 2.50    5377
# 1.00    3851
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1445
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      71
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 1.25       9
# 6.00       6
# 5.75       4
# 0.50       4
# 8.00       2
# 6.25       2
# 6.75       2
# 6.50       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
#Finding the count of condition status of houses
data['condition'].value_counts()
# Out:
# Average      14020
# Good          5677
# Very Good     1701
# Fair           170
# Poor            29
# Name: condition, dtype: int64

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#Model without categorical data which excludes grade
formula = 'price ~ bedrooms + bathrooms + sqft_living + sqft_lot + floors + yr_built'
model = ols(formula=formula, data=data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     4511.
# Date:                Sun, 28 May 2023   Prob (F-statistic):               0.00
# Time:                        07:34:05   Log-Likelihood:            -2.9862e+05
# No. Observations:               21597   AIC:                         5.972e+05
# Df Residuals:                   21590   BIC:                         5.973e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    6.559e+06   1.35e+05     48.643      0.000     6.3e+06    6.82e+06
# ...

# %%
#Model including grade 
formula = 'price ~ bedrooms + bathrooms + sqft_living + sqft_lot + floors + yr_built + grade'
model = ols(formula=formula, data=data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.645
# Model:                            OLS   Adj. R-squared:                  0.645
# Method:                 Least Squares   F-statistic:                     2450.
# Date:                Sun, 28 May 2023   Prob (F-statistic):               0.00
# Time:                        10:40:57   Log-Likelihood:            -2.9621e+05
# No. Observations:               21597   AIC:                         5.925e+05
# Df Residuals:                   21580   BIC:                         5.926e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Scatter plot for categorical data
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,5))
x_columns = ['bedrooms', 'bathrooms']  # Modified line

for xcol, ax in zip(x_columns, axes):  # Modified line
    data.plot(kind='scatter', x=xcol, y='price', ax=ax, alpha=0.4, color='b')  # Modified line

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
x_columns = ['floors', 'grade', 'condition']  # Modified line

for xcol, ax in zip(x_columns, axes):  # Modified line
    data.plot(kind='scatter', x=xcol, y='price', ax=ax, alpha=0.4, color='b')  # Modified line

plt.show()

# %%
#Non categorical or numerical
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,4))
x_columns = ['yr_built', 'sqft_living', 'sqft_lot']  # Modified line

for xcol, ax in zip(x_columns, axes):  # Modified line
    data.plot(kind='scatter', x=xcol, y='price', ax=ax, alpha=0.4, color='b')  # Modified line

plt.show()
